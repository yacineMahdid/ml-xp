# %%
import pandas as pd
from sklearn import *

print(pd.__version__)

sam = pd.Series([.87,.87,.87,.87,.87], index=range(3300, 3305))
print(type(sam))
print(sam)
sam.plot(kind='line');
# Out:
# 0.24.2
# <class 'pandas.core.series.Series'>
# 3300    0.87
# 3301    0.87
# 3302    0.87
# 3303    0.87
# 3304    0.87
# dtype: float64

# %%
sam.plot(kind='line');

# %%
# Doesn't seems to have any error here OP is confused I guess or not enough information
